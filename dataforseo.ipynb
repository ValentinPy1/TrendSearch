# %%
import pandas as pd

keywords = pd.read_csv("unique_keywords.csv")
# Shuffle the keywords dataframe
# keywords = keywords.sample(frac=1, random_state=42).reset_index(drop=True)

keywords.shape
# Out:
# (195600, 1)

# %%
# Split keywords into batches of 10000
keyword_batches = []
batch_size = 1000
num_batches = (len(keywords) // batch_size) + (1 if len(keywords) % batch_size else 0)

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = start_idx + batch_size
    batch = keywords.iloc[start_idx:end_idx]["Keyword"].tolist()
    payload = [{
        "keywords": batch,
        "sort_by": "relevance"
    }]
    keyword_batches.append(payload)

print(f"Split into {len(keyword_batches)} batches")
# for i, batch in enumerate(keyword_batches):
#     print(f"Batch {i+1} size: {len(batch[0]['keywords'])}")
# Out:
# Split into 196 batches

# %%
import dotenv
import os
from dataforseo_client import configuration as dfs_config, api_client as dfs_api_provider
from dataforseo_client.api.keywords_data_api import KeywordsDataApi
from dataforseo_client.rest import ApiException
from dataforseo_client.models.keywords_data_google_ads_search_volume_live_request_info import KeywordsDataGoogleAdsSearchVolumeLiveRequestInfo
import time

dotenv.load_dotenv()
login = os.getenv("DATA_FOR_SEO_LOGIN")
password = os.getenv("DATA_FOR_SEO_PASSWORD")
get_date_from = (time.strftime("%Y-%m-%d", time.gmtime(time.time() - 4 * 365 * 24 * 60 * 60)))
print(get_date_from)

def get_keyword_search_volume(keywords: list[str]):
    """
    Get search volume data for keywords from DataForSEO API
    
    Args:
        keywords (list): List of keyword strings to get data for
        
    Returns:
        dict: API response containing search volume data
    """
    configuration = dfs_config.Configuration(username=login, password=password)
    with dfs_api_provider.ApiClient(configuration) as api_client:
        # Create an instance of the API class
        keywords_api = KeywordsDataApi(api_client)
        
        try:
            # Extract just the keywords list from the payload dictionary
            if isinstance(keywords[0], dict):
                keywords = keywords[0]['keywords']
                
            api_response = keywords_api.google_ads_search_volume_live([KeywordsDataGoogleAdsSearchVolumeLiveRequestInfo(
                keywords=keywords,
                search_partners=True,
                date_from=get_date_from,
                date_to=None
            )])
            return api_response
            
        except ApiException as e:
            print(f"Exception: {e}\n")
            return None
# Out:
# 2021-11-05

# %%
result = get_keyword_search_volume(keyword_batches[0])

# %%
# Save the API response to a file
import json

# Convert the response object to a dictionary
result_dict = result.to_dict()

# Save to JSON file with nice formatting
with open('search_volume_results_0.json', 'w') as f:
    json.dump(result_dict, f, indent=4)

# %%
# Create a directory for search volumes if it doesn't exist
import os
if not os.path.exists('search_volumes'):
    os.makedirs('search_volumes')

# Process each batch and save results
for i, batch in enumerate(keyword_batches[1:]):
    # Get search volume for this batch
    result = get_keyword_search_volume(batch)
    
    if result:
        # Convert response to dictionary
        result_dict = result.to_dict()
        
        # Save to numbered JSON file
        filename = f'search_volumes/search_volume_results_{i}.json'
        with open(filename, 'w') as f:
            json.dump(result_dict, f, indent=4)
        print(f"Saved results for batch {i} to {filename}")
    else:
        print(f"Failed to get results for batch {i}")
# Out:
# Saved results for batch 0 to search_volumes/search_volume_results_0.json
# Saved results for batch 1 to search_volumes/search_volume_results_1.json
# Saved results for batch 2 to search_volumes/search_volume_results_2.json
# Saved results for batch 3 to search_volumes/search_volume_results_3.json
# Saved results for batch 4 to search_volumes/search_volume_results_4.json
# Saved results for batch 5 to search_volumes/search_volume_results_5.json
# Saved results for batch 6 to search_volumes/search_volume_results_6.json
# Saved results for batch 7 to search_volumes/search_volume_results_7.json
# Saved results for batch 8 to search_volumes/search_volume_results_8.json
# Saved results for batch 9 to search_volumes/search_volume_results_9.json
# Saved results for batch 10 to search_volumes/search_volume_results_10.json
# Saved results for batch 11 to search_volumes/search_volume_results_11.json
# Saved results for batch 12 to search_volumes/search_volume_results_12.json
# Saved results for batch 13 to search_volumes/search_volume_results_13.json
# Saved results for batch 14 to search_volumes/search_volume_results_14.json
# Saved results for batch 15 to search_volumes/search_volume_results_15.json
# Saved results for batch 16 to search_volumes/search_volume_results_16.json
# Saved results for batch 17 to search_volumes/search_volume_results_17.json
# Saved results for batch 18 to search_volumes/search_volume_results_18.json
# Saved results for batch 19 to search_volumes/search_volume_results_19.json
# Saved results for batch 20 to search_volumes/search_volume_results_20.json
# Saved results for batch 21 to search_volumes/search_volume_results_21.json
# Saved results for batch 22 to search_volumes/search_volume_results_22.json
# Saved results for batch 23 to search_volumes/search_volume_results_23.json
# Saved results for batch 24 to search_volumes/search_volume_results_24.json
# Saved results for batch 25 to search_volumes/search_volume_results_25.json
# Saved results for batch 26 to search_volumes/search_volume_results_26.json
# Saved results for batch 27 to search_volumes/search_volume_results_27.json
# Saved results for batch 28 to search_volumes/search_volume_results_28.json
# Saved results for batch 29 to search_volumes/search_volume_results_29.json
# Saved results for batch 30 to search_volumes/search_volume_results_30.json
# Saved results for batch 31 to search_volumes/search_volume_results_31.json
# Saved results for batch 32 to search_volumes/search_volume_results_32.json
# Saved results for batch 33 to search_volumes/search_volume_results_33.json
# Saved results for batch 34 to search_volumes/search_volume_results_34.json
# Saved results for batch 35 to search_volumes/search_volume_results_35.json
# Saved results for batch 36 to search_volumes/search_volume_results_36.json
# Saved results for batch 37 to search_volumes/search_volume_results_37.json
# Saved results for batch 38 to search_volumes/search_volume_results_38.json
# Saved results for batch 39 to search_volumes/search_volume_results_39.json
# Saved results for batch 40 to search_volumes/search_volume_results_40.json
# Saved results for batch 41 to search_volumes/search_volume_results_41.json
# Saved results for batch 42 to search_volumes/search_volume_results_42.json
# Saved results for batch 43 to search_volumes/search_volume_results_43.json
# Saved results for batch 44 to search_volumes/search_volume_results_44.json
# Saved results for batch 45 to search_volumes/search_volume_results_45.json
# Saved results for batch 46 to search_volumes/search_volume_results_46.json
# Saved results for batch 47 to search_volumes/search_volume_results_47.json
# Saved results for batch 48 to search_volumes/search_volume_results_48.json
# Saved results for batch 49 to search_volumes/search_volume_results_49.json
# Saved results for batch 50 to search_volumes/search_volume_results_50.json
# Saved results for batch 51 to search_volumes/search_volume_results_51.json
# Saved results for batch 52 to search_volumes/search_volume_results_52.json
# Saved results for batch 53 to search_volumes/search_volume_results_53.json
# Saved results for batch 54 to search_volumes/search_volume_results_54.json
# Saved results for batch 55 to search_volumes/search_volume_results_55.json
# Saved results for batch 56 to search_volumes/search_volume_results_56.json
# Saved results for batch 57 to search_volumes/search_volume_results_57.json
# Saved results for batch 58 to search_volumes/search_volume_results_58.json
# Saved results for batch 59 to search_volumes/search_volume_results_59.json
# Saved results for batch 60 to search_volumes/search_volume_results_60.json
# Saved results for batch 61 to search_volumes/search_volume_results_61.json
# Saved results for batch 62 to search_volumes/search_volume_results_62.json
# Saved results for batch 63 to search_volumes/search_volume_results_63.json
# Saved results for batch 64 to search_volumes/search_volume_results_64.json
# Saved results for batch 65 to search_volumes/search_volume_results_65.json
# Saved results for batch 66 to search_volumes/search_volume_results_66.json
# Saved results for batch 67 to search_volumes/search_volume_results_67.json
# Saved results for batch 68 to search_volumes/search_volume_results_68.json
# Saved results for batch 69 to search_volumes/search_volume_results_69.json
# Saved results for batch 70 to search_volumes/search_volume_results_70.json
# Saved results for batch 71 to search_volumes/search_volume_results_71.json
# Saved results for batch 72 to search_volumes/search_volume_results_72.json
# Saved results for batch 73 to search_volumes/search_volume_results_73.json
# Saved results for batch 74 to search_volumes/search_volume_results_74.json
# Saved results for batch 75 to search_volumes/search_volume_results_75.json
# Saved results for batch 76 to search_volumes/search_volume_results_76.json
# Saved results for batch 77 to search_volumes/search_volume_results_77.json
# Saved results for batch 78 to search_volumes/search_volume_results_78.json
# Saved results for batch 79 to search_volumes/search_volume_results_79.json
# Saved results for batch 80 to search_volumes/search_volume_results_80.json
# Saved results for batch 81 to search_volumes/search_volume_results_81.json
# Saved results for batch 82 to search_volumes/search_volume_results_82.json
# Saved results for batch 83 to search_volumes/search_volume_results_83.json
# Saved results for batch 84 to search_volumes/search_volume_results_84.json
# Saved results for batch 85 to search_volumes/search_volume_results_85.json
# Saved results for batch 86 to search_volumes/search_volume_results_86.json
# Saved results for batch 87 to search_volumes/search_volume_results_87.json
# Saved results for batch 88 to search_volumes/search_volume_results_88.json
# Saved results for batch 89 to search_volumes/search_volume_results_89.json
# Saved results for batch 90 to search_volumes/search_volume_results_90.json
# Saved results for batch 91 to search_volumes/search_volume_results_91.json
# Saved results for batch 92 to search_volumes/search_volume_results_92.json
# Saved results for batch 93 to search_volumes/search_volume_results_93.json
# Saved results for batch 94 to search_volumes/search_volume_results_94.json
# Saved results for batch 95 to search_volumes/search_volume_results_95.json
# Saved results for batch 96 to search_volumes/search_volume_results_96.json
# Saved results for batch 97 to search_volumes/search_volume_results_97.json
# Saved results for batch 98 to search_volumes/search_volume_results_98.json
# Saved results for batch 99 to search_volumes/search_volume_results_99.json
# Saved results for batch 100 to search_volumes/search_volume_results_100.json
# Saved results for batch 101 to search_volumes/search_volume_results_101.json
# Saved results for batch 102 to search_volumes/search_volume_results_102.json
# Saved results for batch 103 to search_volumes/search_volume_results_103.json
# Saved results for batch 104 to search_volumes/search_volume_results_104.json
# Saved results for batch 105 to search_volumes/search_volume_results_105.json
# Saved results for batch 106 to search_volumes/search_volume_results_106.json
# Saved results for batch 107 to search_volumes/search_volume_results_107.json
# Saved results for batch 108 to search_volumes/search_volume_results_108.json
# Saved results for batch 109 to search_volumes/search_volume_results_109.json
# Saved results for batch 110 to search_volumes/search_volume_results_110.json
# Saved results for batch 111 to search_volumes/search_volume_results_111.json
# Saved results for batch 112 to search_volumes/search_volume_results_112.json
# Saved results for batch 113 to search_volumes/search_volume_results_113.json
# Saved results for batch 114 to search_volumes/search_volume_results_114.json
# Saved results for batch 115 to search_volumes/search_volume_results_115.json
# Saved results for batch 116 to search_volumes/search_volume_results_116.json
# Saved results for batch 117 to search_volumes/search_volume_results_117.json
# Saved results for batch 118 to search_volumes/search_volume_results_118.json
# Saved results for batch 119 to search_volumes/search_volume_results_119.json
# Saved results for batch 120 to search_volumes/search_volume_results_120.json
# Saved results for batch 121 to search_volumes/search_volume_results_121.json
# Saved results for batch 122 to search_volumes/search_volume_results_122.json
# Saved results for batch 123 to search_volumes/search_volume_results_123.json
# Saved results for batch 124 to search_volumes/search_volume_results_124.json
# Saved results for batch 125 to search_volumes/search_volume_results_125.json
# Saved results for batch 126 to search_volumes/search_volume_results_126.json
# Saved results for batch 127 to search_volumes/search_volume_results_127.json
# Saved results for batch 128 to search_volumes/search_volume_results_128.json
# Saved results for batch 129 to search_volumes/search_volume_results_129.json
# Saved results for batch 130 to search_volumes/search_volume_results_130.json
# Saved results for batch 131 to search_volumes/search_volume_results_131.json
# Saved results for batch 132 to search_volumes/search_volume_results_132.json
# Saved results for batch 133 to search_volumes/search_volume_results_133.json
# Saved results for batch 134 to search_volumes/search_volume_results_134.json
# Saved results for batch 135 to search_volumes/search_volume_results_135.json
# Saved results for batch 136 to search_volumes/search_volume_results_136.json
# Saved results for batch 137 to search_volumes/search_volume_results_137.json
# Saved results for batch 138 to search_volumes/search_volume_results_138.json
# Saved results for batch 139 to search_volumes/search_volume_results_139.json
# Saved results for batch 140 to search_volumes/search_volume_results_140.json
# Saved results for batch 141 to search_volumes/search_volume_results_141.json
# Saved results for batch 142 to search_volumes/search_volume_results_142.json
# Saved results for batch 143 to search_volumes/search_volume_results_143.json
# Saved results for batch 144 to search_volumes/search_volume_results_144.json
# Saved results for batch 145 to search_volumes/search_volume_results_145.json
# Saved results for batch 146 to search_volumes/search_volume_results_146.json
# Saved results for batch 147 to search_volumes/search_volume_results_147.json
# Saved results for batch 148 to search_volumes/search_volume_results_148.json
# Saved results for batch 149 to search_volumes/search_volume_results_149.json
# Saved results for batch 150 to search_volumes/search_volume_results_150.json
# Saved results for batch 151 to search_volumes/search_volume_results_151.json
# Saved results for batch 152 to search_volumes/search_volume_results_152.json
# Saved results for batch 153 to search_volumes/search_volume_results_153.json
# Saved results for batch 154 to search_volumes/search_volume_results_154.json
# Saved results for batch 155 to search_volumes/search_volume_results_155.json
# Saved results for batch 156 to search_volumes/search_volume_results_156.json
# Saved results for batch 157 to search_volumes/search_volume_results_157.json
# Saved results for batch 158 to search_volumes/search_volume_results_158.json
# Saved results for batch 159 to search_volumes/search_volume_results_159.json
# Saved results for batch 160 to search_volumes/search_volume_results_160.json
# Saved results for batch 161 to search_volumes/search_volume_results_161.json
# Saved results for batch 162 to search_volumes/search_volume_results_162.json
# Saved results for batch 163 to search_volumes/search_volume_results_163.json
# Saved results for batch 164 to search_volumes/search_volume_results_164.json
# Saved results for batch 165 to search_volumes/search_volume_results_165.json
# Saved results for batch 166 to search_volumes/search_volume_results_166.json
# Saved results for batch 167 to search_volumes/search_volume_results_167.json
# Saved results for batch 168 to search_volumes/search_volume_results_168.json
# Saved results for batch 169 to search_volumes/search_volume_results_169.json
# Saved results for batch 170 to search_volumes/search_volume_results_170.json
# Saved results for batch 171 to search_volumes/search_volume_results_171.json
# Saved results for batch 172 to search_volumes/search_volume_results_172.json
# Saved results for batch 173 to search_volumes/search_volume_results_173.json
# Saved results for batch 174 to search_volumes/search_volume_results_174.json
# Saved results for batch 175 to search_volumes/search_volume_results_175.json
# Saved results for batch 176 to search_volumes/search_volume_results_176.json
# Saved results for batch 177 to search_volumes/search_volume_results_177.json
# Saved results for batch 178 to search_volumes/search_volume_results_178.json
# Saved results for batch 179 to search_volumes/search_volume_results_179.json
# Saved results for batch 180 to search_volumes/search_volume_results_180.json
# Saved results for batch 181 to search_volumes/search_volume_results_181.json
# Saved results for batch 182 to search_volumes/search_volume_results_182.json
# Saved results for batch 183 to search_volumes/search_volume_results_183.json
# Saved results for batch 184 to search_volumes/search_volume_results_184.json
# Saved results for batch 185 to search_volumes/search_volume_results_185.json
# Saved results for batch 186 to search_volumes/search_volume_results_186.json
# Saved results for batch 187 to search_volumes/search_volume_results_187.json
# Saved results for batch 188 to search_volumes/search_volume_results_188.json
# Saved results for batch 189 to search_volumes/search_volume_results_189.json
# Saved results for batch 190 to search_volumes/search_volume_results_190.json
# Saved results for batch 191 to search_volumes/search_volume_results_191.json
# Saved results for batch 192 to search_volumes/search_volume_results_192.json
# Saved results for batch 193 to search_volumes/search_volume_results_193.json
# Saved results for batch 194 to search_volumes/search_volume_results_194.json
